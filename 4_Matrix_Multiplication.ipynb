# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi-VIT/Deep-Learning-basics/blob/main/4_Matrix_Multiplication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matrix Multiplication**

# %%
import numpy as np

# %% [markdown]
# **Creating the matrix**

# %%
revenue = np.array([[180, 200, 220], [24, 36, 40], [12,18,20]])
expenses = np.array([[80, 90, 100], [10, 16, 20], [8,10,10]])

# %%
profit = revenue - expenses
profit
# Out:
# array([[100, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %%
price_per_unit = np.array([1000, 400, 1200])
units = np.array([[30, 40, 50], [5, 10, 15], [2, 5, 7]])

# %% [markdown]
# **Concept of Broadcasting in numpy**

# %% [markdown]
# If the shape of two matrix is not shame then it try to expand it

# %%
price_per_unit * units
# Out:
# array([[30000, 16000, 60000],
#        [ 5000,  4000, 18000],
#        [ 2000,  2000,  8400]])

# %% [markdown]
# **Dot Product**

# %%
np.dot(price_per_unit,units)
# Out:
# array([34400, 50000, 64400])

# %% [markdown]
# # **Exercise**

# %% [markdown]
# Exercise: Matrix Math
# Below is some indian companies revenues in US dollars. Using numpy can you convert this into Indian rupees? 1 USD = 75 INR
#
# ![image.png](data:image/png;base64,...)

# %%
matrix = np.array([[200, 220, 250], [68, 79, 105], [110, 140, 180], [80, 85, 90]])

# %%
matrix*75
# Out:
# array([[15000, 16500, 18750],
#        [ 5100,  5925,  7875],
#        [ 8250, 10500, 13500],
#        [ 6000,  6375,  6750]])

# %% [markdown]
# 2. Divine flowers is a flower shop that sells different type of flowers. Below is the table showing how many flowers of each type they sold in different months. Also given are the prices of one flower each. Using this find out their total sales in every month.
#
# ![image.png](data:image/png;base64,...)

# %%
sold = np.array([[50, 60, 25], [10,13,5], [40,70,52 ]])
price = np.array([[20, 30, 15]])

# %%
np.dot(price, sold)
# Out:
# array([[1900, 2640, 1430]])
